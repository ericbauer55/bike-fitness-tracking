# %%
import pandas as pd
pd.set_option("display.max_columns", 100)
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Optional, Any, Union

# %%
IN_CSV_DATA = Path().cwd().parent.parent / "data/3_feature_engineered"
OUT_CSV_DATA = Path().cwd().parent.parent / "data/4_data_split"

# %%
df_summary = pd.read_csv(IN_CSV_DATA/'ride_summary_selected_feature.csv')
df_summary['start_time'] = pd.to_datetime(df_summary['start_time'])

# %%
df_summary
# Out:
#         ride_id          start_time  total_distance_mi  total_weight_lbs  \
# 0    0x5ccb413c 2019-05-02 19:13:00           8.865922               255
# 1    0x5cccc63c 2019-05-03 22:52:44           9.516836               255
# 2    0x5cdbff9c 2019-05-15 12:01:32           8.029630               255
# 3    0x5cdc8391 2019-05-15 21:24:33           8.452656               255
# 4    0x5ce7dff1 2019-05-24 12:13:37           8.018602               255
# ..          ...                 ...                ...               ...
# 362  0x670d1347 2024-10-14 12:49:11          51.392974               265
# 363  0x670e5fca 2024-10-15 12:27:54          69.347088               265
# 364  0x670fd950 2024-10-16 15:18:40          42.582110               265
# 365  0x67128feb 2024-10-18 16:42:19           6.829401               240
# 366  0x6712b38f 2024-10-18 19:14:23           7.416621               250
#
#      avg_cruising_speed  hours_since_last_ride  active_time_ratio  \
# 0             14.574504              45.626944           0.892545
# 1             12.081964              26.995556           0.742305
# 2             14.701154             276.127222           0.896998
# 3             14.453954               8.782500           0.871270
# 4             15.179620             206.166389           0.918417
# ..                  ...                    ...                ...
# 362           11.711288              16.179444           0.510598
# 363           10.892583              15.480833           0.566874
# 364           10.807354              16.252222           0.632865
# 365            9.200931              43.469444           0.871079
# 366           10.271089               1.728889           0.840863
#
#      avg_climb_rate  distance_training_intensity  prior_training_load  year  \
# 0          8.414548                     1.000000             0.000000  2019
# 1          7.339808                     1.000000             0.617508  2019
# 2          7.886564                     0.843729             0.011599  2019
# 3          6.895879                     0.888179             0.731070  2019
# 4          8.303722                     0.842570             0.040566  2019
# ..              ...                          ...                  ...   ...
# 362        5.532752                     0.801922             1.397363  2024
# 363        7.796093                     1.000000             1.524320  2024
# 364        7.040818                     0.614043             1.691895  2024
# 365        3.022623                     0.098481             0.982881  2024
# 366        6.377822                     0.106949             1.034877  2024
#
#      best_power_4s  best_power_5s  best_power_10s  best_power_20s  \
# 0       485.282271     481.991827      462.283537      412.144319
# 1       432.549324     425.735809      389.502414      330.267900
# 2       422.177957     419.814683      393.709515      363.263188
# 3       416.729572     414.718966      393.124198      327.432493
# 4       419.659872     414.650607      402.052528      376.548577
# ..             ...            ...             ...             ...
# 362     534.792543     532.112244      503.479077      417.215989
# 363     594.634267     587.501714      537.774318      418.860416
# 364     570.177700     567.774112      548.419025      482.434774
# 365     273.086014     272.430103      263.061037      224.192676
# 366     465.028710     459.167506      405.763710      297.599365
#
#      best_power_30s  best_power_1m  best_power_2m  best_power_3m  \
# 0        391.244346     314.816769     209.581472     186.631718
# 1        299.166732     225.907473     143.793900     147.597113
# 2        336.841737     271.435198     215.164384     187.689124
# 3        295.389433     231.954659     191.952644     182.999122
# 4        344.272237     262.329945     225.472466     193.519868
# ..              ...            ...            ...            ...
# 362      388.574378     292.872046     219.251373     199.869161
# 363      398.684606     323.496736     242.687937     196.445302
# 364      385.050368     245.512723     212.096148     158.555331
# 365      175.868770     109.288148      79.103927      69.759995
# 366      273.323466     219.395146     142.388049     124.640151
#
#      best_power_4m  best_power_5m  best_power_6m  best_power_10m  \
# 0       179.636006     157.569641     155.009664      142.368486
# 1       129.794118     118.283785     115.819729      107.256435
# 2       188.538262     164.696769     157.267499      154.668660
# 3       175.942510     169.921718     170.186598      156.173244
# 4       187.969739     181.348731     173.976554      167.162898
# ..             ...            ...            ...             ...
# 362     166.802975     159.476129     150.842401      130.382415
# 363     178.850777     169.441686     162.100130      131.514159
# 364     150.821311     139.199750     135.751638      118.114825
# 365      69.608861      62.963294      62.457943       56.677909
# 366     114.878003     107.149501     100.080810      100.918837
#
#      best_power_20m  best_power_30m  best_power_40m  best_power_1h  \
# 0        134.442850      130.264839        0.000000       0.000000
# 1         98.405537       97.000798       94.003892       0.000000
# 2        139.481512      138.606140        0.000000       0.000000
# 3        143.046556      137.236242        0.000000       0.000000
# 4        150.946458      151.020599        0.000000       0.000000
# ..              ...             ...             ...            ...
# 362      118.666776      114.628614      103.221550      91.163787
# 363      114.950710      102.072083       94.471626      87.931443
# 364       88.321449       78.065144       81.569771      72.379041
# 365       49.038385       42.754810       39.201646       0.000000
# 366       84.695968       80.986328       76.946954       0.000000
#
#      best_power_2h
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# ..             ...
# 362      74.247182
# 363      75.476319
# 364      65.034151
# 365       0.000000
# 366       0.000000
#
# [367 rows x 28 columns]
