# %%
import pandas as pd
pd.set_option("display.max_columns", 100)
import numpy as np
np.set_printoptions(suppress=True)
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Optional, Any, Union

# %%
IN_CSV_DATA = Path().cwd().parent.parent / "data/4_data_split"
OUT_MODEL_DATA = Path().cwd().parent.parent / "data/5_models"

# %% [markdown]
# # 1. Load in Training and Test Datasets

# %%
df_train = pd.read_csv(IN_CSV_DATA/'prepared_train.csv')
df_test = pd.read_csv(IN_CSV_DATA/'prepared_test.csv')

# %%
numerical_feature_cols = ['total_distance_mi','total_weight_lbs','avg_cruising_speed', 'log_hours_since_last_ride',
                            'active_time_ratio', 'avg_climb_rate', 'distance_training_intensity','prior_training_load']
categorical_feature_cols = []#['year']
feature_cols = numerical_feature_cols + categorical_feature_cols

target_cols = ['best_power_4s', 'best_power_5s',
                'best_power_10s', 'best_power_20s', 'best_power_30s', 'best_power_1m',
                'best_power_2m', 'best_power_3m', 'best_power_4m', 'best_power_5m',
                'best_power_6m', 'best_power_10m', 'best_power_20m', 'best_power_30m',
                'best_power_40m', 'best_power_1h', 'best_power_2h']

# %%
X_train, y_train = df_train[feature_cols].values, df_train[target_cols].values
X_test, y_test = df_test[feature_cols].values, df_test[target_cols].values

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict, TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, root_mean_squared_log_error
from sklearn.multioutput import MultiOutputRegressor, RegressorChain

# %%
SCORING = 'r2'

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
tss_cv = TimeSeriesSplit(n_splits=5)

# %% [markdown]
# # 1a. Full Targets Vector Regressor

# %%
kridge_reg = KernelRidge()

# %%
param_grid = [{'kernel':['rbf','polynomial','sigmoid', 'linear'],
               'gamma':[0.001, 0.01, 0.1, 0.5,1,5,10], 
               }]
kridge_reg_gridcv = GridSearchCV(kridge_reg, param_grid, cv=tss_cv, n_jobs=-1, 
                             refit=True, return_train_score=True,
                             scoring=SCORING, verbose=1
                            )

# %%
# fitting the model for grid search
kridge_reg_gridcv.fit(X_train, y_train)

# print the best parameter set after tuning
print(kridge_reg_gridcv.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# {'gamma': 0.01, 'kernel': 'polynomial'}

# %%
cv_results = kridge_reg_gridcv.cv_results_

for train_r2, test_r2, params in zip(cv_results['mean_train_score'], cv_results['mean_test_score'], cv_results['params']):
    print(f'For params:{params}')
    print(f'\t- Train R^2={train_r2} --> Test R^2={test_r2}')
    print('-'*50)
# Out:
# For params:{'gamma': 0.001, 'kernel': 'rbf'}
# 	- Train R^2=0.21764856218696402 --> Test R^2=0.10342227694171058
# --------------------------------------------------
# For params:{'gamma': 0.001, 'kernel': 'polynomial'}
# 	- Train R^2=0.2697208193130315 --> Test R^2=0.14626651744840585
# --------------------------------------------------
# For params:{'gamma': 0.001, 'kernel': 'sigmoid'}
# 	- Train R^2=0.06469012696228682 --> Test R^2=-0.01083588613658076
# --------------------------------------------------
# For params:{'gamma': 0.001, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 0.01, 'kernel': 'rbf'}
# 	- Train R^2=0.48994427434294785 --> Test R^2=0.25884715679840087
# --------------------------------------------------
# For params:{'gamma': 0.01, 'kernel': 'polynomial'}
# 	- Train R^2=0.5408061481512128 --> Test R^2=0.2913925854257754
# --------------------------------------------------
# For params:{'gamma': 0.01, 'kernel': 'sigmoid'}
# 	- Train R^2=0.30094880805528956 --> Test R^2=0.17318493589140405
# --------------------------------------------------
# For params:{'gamma': 0.01, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 0.1, 'kernel': 'rbf'}
# 	- Train R^2=0.5626968148734728 --> Test R^2=-0.8832779638086814
# --------------------------------------------------
# For params:{'gamma': 0.1, 'kernel': 'polynomial'}
# 	- Train R^2=0.7866698463153841 --> Test R^2=-0.706636012204096
# --------------------------------------------------
# For params:{'gamma': 0.1, 'kernel': 'sigmoid'}
# 	- Train R^2=-199.44889902131786 --> Test R^2=-188.4864256574365
# --------------------------------------------------
# For params:{'gamma': 0.1, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 0.5, 'kernel': 'rbf'}
# 	- Train R^2=0.07490073242028306 --> Test R^2=-4.641041467993783
# --------------------------------------------------
# For params:{'gamma': 0.5, 'kernel': 'polynomial'}
# 	- Train R^2=0.9206844051167229 --> Test R^2=-144.87188260711008
# --------------------------------------------------
# For params:{'gamma': 0.5, 'kernel': 'sigmoid'}
# 	- Train R^2=-9.775409427963666 --> Test R^2=-60.57008600435866
# --------------------------------------------------
# For params:{'gamma': 0.5, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 1, 'kernel': 'rbf'}
# 	- Train R^2=-0.6613905321495495 --> Test R^2=-7.59419602096858
# --------------------------------------------------
# For params:{'gamma': 1, 'kernel': 'polynomial'}
# 	- Train R^2=0.9458835707401965 --> Test R^2=-360.48257008849436
# --------------------------------------------------
# For params:{'gamma': 1, 'kernel': 'sigmoid'}
# 	- Train R^2=-52.54051815952554 --> Test R^2=-470.42957903453214
# --------------------------------------------------
# For params:{'gamma': 1, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 5, 'kernel': 'rbf'}
# 	- Train R^2=-2.114354954568553 --> Test R^2=-10.87824903937326
# --------------------------------------------------
# For params:{'gamma': 5, 'kernel': 'polynomial'}
# 	- Train R^2=0.9603487689145919 --> Test R^2=-546.9781248377868
# --------------------------------------------------
# For params:{'gamma': 5, 'kernel': 'sigmoid'}
# 	- Train R^2=-134.3231270312168 --> Test R^2=-2438.7404192527997
# --------------------------------------------------
# For params:{'gamma': 5, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------
# For params:{'gamma': 10, 'kernel': 'rbf'}
# 	- Train R^2=-2.2759555468846293 --> Test R^2=-10.943228730288768
# --------------------------------------------------
# For params:{'gamma': 10, 'kernel': 'polynomial'}
# 	- Train R^2=0.9612879590337883 --> Test R^2=-631.9234390273905
# --------------------------------------------------
# For params:{'gamma': 10, 'kernel': 'sigmoid'}
# 	- Train R^2=-43.279222811372875 --> Test R^2=-687.4062119151653
# --------------------------------------------------
# For params:{'gamma': 10, 'kernel': 'linear'}
# 	- Train R^2=-8.187249476129384 --> Test R^2=-19.63712035462934
# --------------------------------------------------

# %%
model_kridge_reg = kridge_reg_gridcv.best_estimator_

# %% [markdown]
# # 1b. Individual Target Regressors `MultiOutputRegressor`

# %%
param_grid = [{'estimator__kernel':['rbf','polynomial','sigmoid','linear'],
               'estimator__gamma':[0.001, 0.01, 0.1, 0.5,1,5,10], 
               }]

MO_kridge_reg = MultiOutputRegressor(KernelRidge())

kridge_reg_gridcv = GridSearchCV(MO_kridge_reg, param_grid, cv=tss_cv, n_jobs=-1, 
                             refit=True, return_train_score=True,
                             scoring=SCORING, verbose=1
                            )

# %%
# fitting the model for grid search
kridge_reg_gridcv.fit(X_train, y_train)

# print the best parameter set after tuning
print(kridge_reg_gridcv.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
# ...
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# {'estimator__gamma': 0.01, 'estimator__kernel': 'polynomial'}

# %%
cv_results = kridge_reg_gridcv.cv_results_

for train_r2, test_r2, params in zip(cv_results['mean_train_score'], cv_results['mean_test_score'], cv_results['params']):
    print(f'For params:{params}')
    print(f'\t- Train R^2={train_r2} --> Test R^2={test_r2}')
    print('-'*50)
# Out:
# For params:{'estimator__gamma': 0.001, 'estimator__kernel': 'rbf'}
# 	- Train R^2=0.217648562186964 --> Test R^2=0.10342227694171069
# --------------------------------------------------
# For params:{'estimator__gamma': 0.001, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.2697208193130315 --> Test R^2=0.1462665174484057
# --------------------------------------------------
# For params:{'estimator__gamma': 0.001, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=0.06469012696228683 --> Test R^2=-0.010835886136580675
# --------------------------------------------------
# For params:{'estimator__gamma': 0.001, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 0.01, 'estimator__kernel': 'rbf'}
# 	- Train R^2=0.48994427434294785 --> Test R^2=0.2588471567984009
# --------------------------------------------------
# For params:{'estimator__gamma': 0.01, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.5408061481512128 --> Test R^2=0.2913925854257755
# --------------------------------------------------
# For params:{'estimator__gamma': 0.01, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=0.3009488080552895 --> Test R^2=0.17318493589140413
# --------------------------------------------------
# For params:{'estimator__gamma': 0.01, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 0.1, 'estimator__kernel': 'rbf'}
# 	- Train R^2=0.5626968148734728 --> Test R^2=-0.8832779638086816
# --------------------------------------------------
# For params:{'estimator__gamma': 0.1, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.7866698463153841 --> Test R^2=-0.7066360122040969
# --------------------------------------------------
# For params:{'estimator__gamma': 0.1, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=-199.44889902131777 --> Test R^2=-188.48642565743629
# --------------------------------------------------
# For params:{'estimator__gamma': 0.1, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 0.5, 'estimator__kernel': 'rbf'}
# 	- Train R^2=0.07490073242028299 --> Test R^2=-4.641041467993783
# --------------------------------------------------
# For params:{'estimator__gamma': 0.5, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.9206844051167227 --> Test R^2=-144.87188260711042
# --------------------------------------------------
# For params:{'estimator__gamma': 0.5, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=-9.775409427963663 --> Test R^2=-60.57008600435866
# --------------------------------------------------
# For params:{'estimator__gamma': 0.5, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 1, 'estimator__kernel': 'rbf'}
# 	- Train R^2=-0.6613905321495495 --> Test R^2=-7.59419602096858
# --------------------------------------------------
# For params:{'estimator__gamma': 1, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.9458835707401967 --> Test R^2=-360.4825700884943
# --------------------------------------------------
# For params:{'estimator__gamma': 1, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=-52.540518159525526 --> Test R^2=-470.4295790345321
# --------------------------------------------------
# For params:{'estimator__gamma': 1, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 5, 'estimator__kernel': 'rbf'}
# 	- Train R^2=-2.114354954568553 --> Test R^2=-10.87824903937326
# --------------------------------------------------
# For params:{'estimator__gamma': 5, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.9603487689146138 --> Test R^2=-546.9781248377126
# --------------------------------------------------
# For params:{'estimator__gamma': 5, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=-134.32312703121661 --> Test R^2=-2438.740419252796
# --------------------------------------------------
# For params:{'estimator__gamma': 5, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------
# For params:{'estimator__gamma': 10, 'estimator__kernel': 'rbf'}
# 	- Train R^2=-2.275955546884629 --> Test R^2=-10.943228730288768
# --------------------------------------------------
# For params:{'estimator__gamma': 10, 'estimator__kernel': 'polynomial'}
# 	- Train R^2=0.9612879590338792 --> Test R^2=-631.9234390281872
# --------------------------------------------------
# For params:{'estimator__gamma': 10, 'estimator__kernel': 'sigmoid'}
# 	- Train R^2=-43.27922281137287 --> Test R^2=-687.4062119151652
# --------------------------------------------------
# For params:{'estimator__gamma': 10, 'estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476129395 --> Test R^2=-19.63712035462936
# --------------------------------------------------

# %%
model_MO_kridge_reg = kridge_reg_gridcv.best_estimator_

# %% [markdown]
# # 1c. Chain Regressor

# %%
param_grid = [{'base_estimator__kernel':['rbf','polynomial','sigmoid','linear'],
               'base_estimator__gamma':[0.001, 0.01, 0.1, 0.5,1,5,10], 
               }]
RC_kridge_reg = RegressorChain(KernelRidge(), order='random', random_state=42)

kridge_reg_gridcv = GridSearchCV(RC_kridge_reg, param_grid, cv=tss_cv, n_jobs=-1, 
                             refit=True, return_train_score=True,
                             scoring=SCORING, verbose=1
                            )

# %%
# fitting the model for grid search
kridge_reg_gridcv.fit(X_train, y_train)

# print the best parameter set after tuning
print(kridge_reg_gridcv.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
# ...
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:252: LinAlgWarning: Ill-conditioned matrix (rcond=3.00486e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:252: LinAlgWarning: Ill-conditioned matrix (rcond=4.45071e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:252: LinAlgWarning: Ill-conditioned matrix (rcond=3.37831e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1499: RuntimeWarning: overflow encountered in power
#   K **= degree
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 831, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/multioutput.py", line 681, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/kernel_ridge.py", line 238, in predict
#     X = validate_data(self, X, accept_sparse=("csr", "csc"), reset=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KernelRidge does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# {'base_estimator__gamma': 0.01, 'base_estimator__kernel': 'sigmoid'}
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [ -9.74179632          nan  -0.05539899 -19.63712035 -10.37621053
#           nan  -0.04912192 -19.63712035 -10.58850931          nan
#  -13.80177283 -19.63712035 -10.77523097          nan -22.02970304
#  -19.63712035 -10.85657143          nan -46.62526832 -19.63712035
#  -10.94506251          nan -83.05731981 -19.63712035 -10.94648769
#           nan -49.24299823 -19.63712035]
#   warnings.warn(
# /home/ebauer/Documents/Code_Repos/bike-fitness-tracking/venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the train scores are non-finite: [-10.72225283          nan   0.00111663  -8.18724948 -11.68976565
#           nan   0.01029568  -8.18724948 -11.89444161          nan
#  -24.25508786  -8.18724948 -12.00332487          nan  -8.41543668
#   -8.18724948 -12.03416731          nan -13.52087903  -8.18724948
#  -12.07812133          nan -14.65970539  -8.18724948 -12.0827493
#           nan -12.64334373  -8.18724948]
#   warnings.warn(

# %%
cv_results = kridge_reg_gridcv.cv_results_

for train_r2, test_r2, params in zip(cv_results['mean_train_score'], cv_results['mean_test_score'], cv_results['params']):
    print(f'For params:{params}')
    print(f'\t- Train R^2={train_r2} --> Test R^2={test_r2}')
    print('-'*50)
# Out:
# For params:{'base_estimator__gamma': 0.001, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-10.722252834660424 --> Test R^2=-9.741796320970234
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.001, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.001, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=0.001116631267365482 --> Test R^2=-0.055398990676212366
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.001, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.01, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-11.689765654332376 --> Test R^2=-10.376210530181895
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.01, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.01, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=0.010295681904644003 --> Test R^2=-0.049121919958571646
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.01, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.1, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-11.894441613606993 --> Test R^2=-10.588509312629565
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.1, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.1, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=-24.255087857987082 --> Test R^2=-13.801772829310611
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.1, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.5, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-12.003324871114057 --> Test R^2=-10.77523096631234
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.5, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.5, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=-8.415436675673037 --> Test R^2=-22.029703040256017
# --------------------------------------------------
# For params:{'base_estimator__gamma': 0.5, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 1, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-12.034167311129682 --> Test R^2=-10.856571426428987
# --------------------------------------------------
# For params:{'base_estimator__gamma': 1, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 1, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=-13.520879025250514 --> Test R^2=-46.625268321877186
# --------------------------------------------------
# For params:{'base_estimator__gamma': 1, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 5, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-12.078121332899698 --> Test R^2=-10.9450625088909
# --------------------------------------------------
# For params:{'base_estimator__gamma': 5, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 5, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=-14.659705387107568 --> Test R^2=-83.05731981122274
# --------------------------------------------------
# For params:{'base_estimator__gamma': 5, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------
# For params:{'base_estimator__gamma': 10, 'base_estimator__kernel': 'rbf'}
# 	- Train R^2=-12.082749301233143 --> Test R^2=-10.946487692848766
# --------------------------------------------------
# For params:{'base_estimator__gamma': 10, 'base_estimator__kernel': 'polynomial'}
# 	- Train R^2=nan --> Test R^2=nan
# --------------------------------------------------
# For params:{'base_estimator__gamma': 10, 'base_estimator__kernel': 'sigmoid'}
# 	- Train R^2=-12.64334372623081 --> Test R^2=-49.24299823027198
# --------------------------------------------------
# For params:{'base_estimator__gamma': 10, 'base_estimator__kernel': 'linear'}
# 	- Train R^2=-8.187249476119487 --> Test R^2=-19.637120353009205
# --------------------------------------------------

# %%
model_RC_kridge_reg = kridge_reg_gridcv.best_estimator_

# %% [markdown]
# # 2. Save Models

# %%
import pickle

pickle.dump(model_kridge_reg, open(OUT_MODEL_DATA / 'kridge_reg_AllAtOnce.pkl','wb'))
pickle.dump(model_MO_kridge_reg, open(OUT_MODEL_DATA / 'kridge_reg_MultiOutput.pkl','wb'))
pickle.dump(model_RC_kridge_reg, open(OUT_MODEL_DATA / 'kridge_reg_RegChain.pkl','wb'))
